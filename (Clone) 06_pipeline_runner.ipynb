# %%
dbutils.notebook.run(
    "/Workspace/Users/anshu.accent@gmail.com/healthcare_project_pipe/01_setup",
    0
)

dbutils.notebook.run(
    "/Workspace/Users/anshu.accent@gmail.com/healthcare_project_pipe/02_bronze_ingestion",
    0
)

dbutils.notebook.run(
    "/Workspace/Users/anshu.accent@gmail.com/healthcare_project_pipe/03_silver_transformation",
    0
)

dbutils.notebook.run(
    "/Workspace/Users/anshu.accent@gmail.com/healthcare_project_pipe/04_gold_transformation",
    0
)

dbutils.notebook.run(
    "/Workspace/Users/anshu.accent@gmail.com/healthcare_project_pipe/05_data_quality_checks & incremental",
    0
)
